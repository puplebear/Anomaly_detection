# %% [markdown]
# ## Bearing Failure Anomaly Detection
# In this workbook, we use an autoencoder neural network to identify vibrational anomalies from sensor readings in a set of bearings. The goal is to be able to predict future bearing failures before they happen. The vibrational sensor readings are from the NASA Acoustics and Vibration Database. Each data set consists of individual files that are 1-second vibration signal snapshots recorded at 10 minute intervals. Each file contains 20,480 sensor data points that were obtained by reading the bearing sensors at a sampling rate of 20 kHz.
#
# This autoencoder neural network model is created using Long Short-Term Memory (LSTM) recurrent neural network (RNN) cells within the Keras / TensorFlow framework.

# %%
# import libraries
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.externals import joblib
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy.random import seed
from tensorflow import set_random_seed
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)


from keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from keras.models import Model
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
# set random seed
seed(10)
set_random_seed(10)

# %% [markdown]
# # Data loading and pre-processing
# An assumption is that mechanical degradation in the bearings occurs gradually over time; therefore, we use one datapoint every 10 minutes in the analysis. Each 10 minute datapoint is aggregated by using the mean absolute value of the vibration recordings over the 20,480 datapoints in each file. We then merge together everything in a single dataframe.
#
# 10분간 데이터를 수집해 하나의 포인트로 설정
#
# 10분 데이터는 20480개의 데이터가 수집되고 이를 평균내서 사용

# %%
# 10분간 데이터를 수집하고 하나의 포인트로 설정 
### 
# data_dir = 'data'
# lst = os.listdir(data_dir)
# lst.sort()

# dataset = pd.read_csv(os.path.join(data_dir, '2004.02.16.16.22.39'), sep='\t')
# print('dataset : ', dataset.shape)
# dataset.describe()
# dataset_mean_abs = np.array(dataset.abs().mean())
# print('dataset_mean_abs : ',dataset_mean_abs.shape)
# dataset_mean_abs = pd.DataFrame(dataset_mean_abs.reshape(1,4))
# print('dataset_mean_abs_reshape : ',dataset_mean_abs.shape)
# dataset_mean_abs.index = ['2004.02.16.16.22.39']
# dataset_mean_abs.describe()
# Out:
# dataset :  (20479, 4)
#              -0.049        -0.115         0.020         0.039
# count  20479.000000  20479.000000  20479.000000  20479.000000
# mean      -0.001822     -0.001350     -0.001751     -0.002670
# std        0.094523      0.093683      0.098081      0.056045
# min       -0.466000     -0.376000     -0.779000     -0.239000
# 25%       -0.061000     -0.066000     -0.063000     -0.039000
# 50%       -0.002000     -0.002000     -0.002000     -0.002000
# 75%        0.059000      0.061000      0.061000      0.034000
# max        0.479000      0.466000      0.647000      0.234000

# %%
# load, average and merge sensor samples
data_dir = 'data'
merged_data = pd.DataFrame()

for filename in os.listdir(data_dir):
    dataset = pd.read_csv(os.path.join(data_dir, filename), sep='\t')
    dataset_mean_abs = np.array(dataset.abs().mean())
    dataset_mean_abs = pd.DataFrame(dataset_mean_abs.reshape(1,4))
    dataset_mean_abs.index = [filename]
    merged_data = merged_data.append(dataset_mean_abs)
    
merged_data.columns = ['Bearing 1', 'Bearing 2', 'Bearing 3', 'Bearing 4']

# %%
merged_data.head()
# Out:
#                      Bearing 1  Bearing 2  Bearing 3  Bearing 4
# 2004.02.16.16.22.39   0.073814   0.074713   0.075640   0.044425
# 2004.02.15.16.42.39   0.059662   0.073159   0.075952   0.042869
# 2004.02.17.16.52.39   0.092946   0.078138   0.077772   0.050036
# 2004.02.15.12.22.39   0.060525   0.074383   0.078142   0.044174
# 2004.02.17.02.42.39   0.078344   0.074184   0.079004   0.046181

# %%
# transform data file index to datetime and sort in chronological order
# 시간 양식을 수정
merged_data.index = pd.to_datetime(merged_data.index, format='%Y.%m.%d.%H.%M.%S')
# 시간 순으로  sort
merged_data = merged_data.sort_index()
# csv로 저장
merged_data.to_csv('Averaged_BearingTest_Dataset.csv')
print("Dataset shape:", merged_data.shape)
merged_data.head()
# Out:
# Dataset shape: (982, 4)
#                      Bearing 1  Bearing 2  Bearing 3  Bearing 4
# 2004-02-12 10:52:39   0.060236   0.074227   0.083926   0.044443
# 2004-02-12 11:02:39   0.061455   0.073844   0.084457   0.045081
# 2004-02-12 11:12:39   0.061361   0.075609   0.082837   0.045118
# 2004-02-12 11:22:39   0.061665   0.073279   0.084879   0.044172
# 2004-02-12 11:32:39   0.061944   0.074593   0.082626   0.044659

# %% [markdown]
# # Define train/test data
# Before setting up the models, we need to define train/test data. To do this, we perform a simple split where we train on the first part of the dataset (which should represent normal operating conditions) and test on the remaining parts of the dataset leading up to the bearing failure.

# %%
# train은 정상 데이터로 구성
## 그런데 왜 나중에 train_X로 테스트 할때 비정상 구간이 나오는 걸까??
train = merged_data['2004-02-12 10:52:39': '2004-02-15 12:52:39']

test = merged_data['2004-02-15 12:52:39':]
print("Training dataset shape:", train.shape)
print("Test dataset shape:", test.shape)
# Out:
# Training dataset shape: (445, 4)
# Test dataset shape: (538, 4)

# %%
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train['Bearing 1'], label='Bearing 1', color='blue', animated = True, linewidth=1)
ax.plot(train['Bearing 2'], label='Bearing 2', color='red', animated = True, linewidth=1)
ax.plot(train['Bearing 3'], label='Bearing 3', color='green', animated = True, linewidth=1)
ax.plot(train['Bearing 4'], label='Bearing 4', color='black', animated = True, linewidth=1)
plt.legend(loc='lower left')
ax.set_title('Bearing Sensor Training Data', fontsize=16)
plt.show()

# %% [markdown]
# Let’s get a different perspective of the data by transforming the signal from the time domain to the frequency domain using a discrete Fourier transform.

# %%
# transforming data from the time domain to the frequency domain using fast Fourier transform
train_fft = np.fft.fft(train)
test_fft = np.fft.fft(test)

# %%
# frequencies of the healthy sensor signal
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train_fft[:,0].real, label='Bearing 1', color='blue', animated = True, linewidth=1)
ax.plot(train_fft[:,1].imag, label='Bearing 2', color='red', animated = True, linewidth=1)
ax.plot(train_fft[:,2].real, label='Bearing 3', color='green', animated = True, linewidth=1)
ax.plot(train_fft[:,3].real, label='Bearing 4', color='black', animated = True, linewidth=1)
plt.legend(loc='lower left')
ax.set_title('Bearing Sensor Training Frequency Data', fontsize=16)
plt.show()

# %%
# frequencies of the degrading sensor signal
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(test_fft[:,0].real, label='Bearing 1', color='blue', animated = True, linewidth=1)
ax.plot(test_fft[:,1].imag, label='Bearing 2', color='red', animated = True, linewidth=1)
ax.plot(test_fft[:,2].real, label='Bearing 3', color='green', animated = True, linewidth=1)
ax.plot(test_fft[:,3].real, label='Bearing 4', color='black', animated = True, linewidth=1)
plt.legend(loc='lower left')
ax.set_title('Bearing Sensor Test Frequency Data', fontsize=16)
plt.show()

# %%
# normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(train)
X_test = scaler.transform(test)
scaler_filename = "scaler_data"
joblib.dump(scaler, scaler_filename)
# Out:
# ['scaler_data']

# %%
# reshape inputs for LSTM [samples, timesteps, features]
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
print("Training data shape:", X_train.shape)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
print("Test data shape:", X_test.shape)
# Out:
# Training data shape: (445, 1, 4)
# Test data shape: (538, 1, 4)

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1, 4)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 1, 4)              0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 1, 4)              68
# =================================================================
# Total params: 3,236
# Trainable params: 3,236
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model to the data
nb_epochs = 100
batch_size = 10
history = model.fit(X_train, X_train, epochs=nb_epochs, batch_size=batch_size,
                    validation_split=0.05).history
# Out:
# Train on 422 samples, validate on 23 samples
# Epoch 1/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.4472 - val_loss: 0.3244
# Epoch 2/100
# 422/422 [==============================] - 0s 996us/step - loss: 0.3899 - val_loss: 0.2580
# Epoch 3/100
# 422/422 [==============================] - 0s 939us/step - loss: 0.3122 - val_loss: 0.1798
# Epoch 4/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.2061 - val_loss: 0.1587
# Epoch 5/100
# 422/422 [==============================] - 0s 958us/step - loss: 0.1277 - val_loss: 0.1404
# Epoch 6/100
# 422/422 [==============================] - 0s 940us/step - loss: 0.1085 - val_loss: 0.1227
# Epoch 7/100
# 422/422 [==============================] - 0s 931us/step - loss: 0.1040 - val_loss: 0.1187
# Epoch 8/100
# 422/422 [==============================] - 0s 929us/step - loss: 0.1025 - val_loss: 0.1147
# Epoch 9/100
# 422/422 [==============================] - 0s 870us/step - loss: 0.1020 - val_loss: 0.1142
# Epoch 10/100
# 422/422 [==============================] - 0s 905us/step - loss: 0.1012 - val_loss: 0.1138
# Epoch 11/100
# 422/422 [==============================] - 0s 868us/step - loss: 0.1014 - val_loss: 0.1136
# Epoch 12/100
# 422/422 [==============================] - 0s 902us/step - loss: 0.1010 - val_loss: 0.1121
# Epoch 13/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.1009 - val_loss: 0.1132
# Epoch 14/100
# 422/422 [==============================] - 0s 883us/step - loss: 0.1005 - val_loss: 0.1114
# Epoch 15/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.1006 - val_loss: 0.1112
# Epoch 16/100
# 422/422 [==============================] - 0s 930us/step - loss: 0.1004 - val_loss: 0.1112
# Epoch 17/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.1000 - val_loss: 0.1123
# Epoch 18/100
# 422/422 [==============================] - 0s 884us/step - loss: 0.0997 - val_loss: 0.1110
# Epoch 19/100
# 422/422 [==============================] - 0s 961us/step - loss: 0.0998 - val_loss: 0.1099
# Epoch 20/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0999 - val_loss: 0.1110
# Epoch 21/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0995 - val_loss: 0.1091
# Epoch 22/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0992 - val_loss: 0.1107
# Epoch 23/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0988 - val_loss: 0.1097
# Epoch 24/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0988 - val_loss: 0.1086
# Epoch 25/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0989 - val_loss: 0.1081
# Epoch 26/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0983 - val_loss: 0.1091
# Epoch 27/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0985 - val_loss: 0.1086
# Epoch 28/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0980 - val_loss: 0.1060
# Epoch 29/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0977 - val_loss: 0.1066
# Epoch 30/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0976 - val_loss: 0.1070
# Epoch 31/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0975 - val_loss: 0.1062
# Epoch 32/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0973 - val_loss: 0.1049
# Epoch 33/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0971 - val_loss: 0.1025
# Epoch 34/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0970 - val_loss: 0.1036
# Epoch 35/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0968 - val_loss: 0.1042
# Epoch 36/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0966 - val_loss: 0.1047
# Epoch 37/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0966 - val_loss: 0.1026
# Epoch 38/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0963 - val_loss: 0.1044
# Epoch 39/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0964 - val_loss: 0.1017
# Epoch 40/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0961 - val_loss: 0.1006
# Epoch 41/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0960 - val_loss: 0.1012
# Epoch 42/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.1019
# Epoch 43/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0960 - val_loss: 0.0996
# Epoch 44/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0955 - val_loss: 0.1012
# Epoch 45/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0961 - val_loss: 0.1012
# Epoch 46/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0957 - val_loss: 0.0998
# Epoch 47/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0952 - val_loss: 0.0987
# Epoch 48/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0953 - val_loss: 0.0993
# Epoch 49/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0954 - val_loss: 0.0989
# Epoch 50/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0953 - val_loss: 0.0994
# Epoch 51/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0954 - val_loss: 0.0984
# Epoch 52/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0955 - val_loss: 0.0993
# Epoch 53/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0951 - val_loss: 0.0979
# Epoch 54/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0947 - val_loss: 0.0987
# Epoch 55/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0950 - val_loss: 0.0976
# Epoch 56/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0946 - val_loss: 0.0984
# Epoch 57/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0949 - val_loss: 0.0968
# Epoch 58/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0947 - val_loss: 0.0989
# Epoch 59/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0948 - val_loss: 0.0963
# Epoch 60/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0949 - val_loss: 0.0967
# Epoch 61/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0947 - val_loss: 0.0970
# Epoch 62/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0946 - val_loss: 0.0954
# Epoch 63/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0947 - val_loss: 0.0960
# Epoch 64/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0950 - val_loss: 0.0977
# Epoch 65/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0951 - val_loss: 0.0962
# Epoch 66/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0947 - val_loss: 0.0945
# Epoch 67/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0944 - val_loss: 0.0956
# Epoch 68/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0943 - val_loss: 0.0946
# Epoch 69/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0942 - val_loss: 0.0958
# Epoch 70/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0943 - val_loss: 0.0953
# Epoch 71/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0942 - val_loss: 0.0955
# Epoch 72/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0941 - val_loss: 0.0951
# Epoch 73/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0943 - val_loss: 0.0950
# Epoch 74/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0943 - val_loss: 0.0928
# Epoch 75/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 76/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0939 - val_loss: 0.0941
# Epoch 77/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0945 - val_loss: 0.0934
# Epoch 78/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0941 - val_loss: 0.0951
# Epoch 79/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0938 - val_loss: 0.0940
# Epoch 80/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0939 - val_loss: 0.0927
# Epoch 81/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0939 - val_loss: 0.0941
# Epoch 82/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0938 - val_loss: 0.0935
# Epoch 83/100
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0939 - val_loss: 0.0931
# Epoch 84/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0942 - val_loss: 0.0941
# Epoch 85/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0938 - val_loss: 0.0939
# Epoch 86/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 87/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0937 - val_loss: 0.0944
# Epoch 88/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0940 - val_loss: 0.0943
# Epoch 89/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0938 - val_loss: 0.0926
# Epoch 90/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0937 - val_loss: 0.0927
# Epoch 91/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0936 - val_loss: 0.0924
# Epoch 92/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0938 - val_loss: 0.0929
# Epoch 93/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0938 - val_loss: 0.0922
# Epoch 94/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0938 - val_loss: 0.0923
# Epoch 95/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0940 - val_loss: 0.0913
# Epoch 96/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0937 - val_loss: 0.0925
# Epoch 97/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0941 - val_loss: 0.0925
# Epoch 98/100
# 422/422 [==============================] - 0s 1ms/step - loss: 0.0939 - val_loss: 0.0932
# Epoch 99/100
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0937 - val_loss: 0.0923
# Epoch 100/100
# 422/422 [==============================] - 1s 1ms/step - loss: 0.0937 - val_loss: 0.0922

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Distribution of Loss Function
# By plotting the distribution of the calculated loss in the training set, one can use this to identify a suitable threshold value for identifying an anomaly. In doing this, one can make sure that this threshold is set above the “noise level” and that any flagged anomalies should be statistically significant above the background noise.

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=train.columns)
X_pred.index = train.index

scored = pd.DataFrame(index=train.index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue')
plt.xlim([0.0,.5])
# Out:
# /home/rain/anaconda3/envs/py36/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 0.5)

# %%
scored['Loss_mae'].max()
# Out:
# 0.24894171738973458

# %% [markdown]
# From the above loss distribution, let's try a threshold value of 0.275 for flagging an anomaly. We can then calculate the loss in the test set to check when the output crosses the anomaly threshold.

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=test.columns)
X_pred.index = test.index

scored = pd.DataFrame(index=test.index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = 0.275
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
#                      Loss_mae  Threshold  Anomaly
# 2004-02-15 12:52:39  0.094382      0.275    False
# 2004-02-15 13:02:39  0.171183      0.275    False
# 2004-02-15 13:12:39  0.066514      0.275    False
# 2004-02-15 13:22:39  0.054245      0.275    False
# 2004-02-15 13:32:39  0.037089      0.275    False

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=train.columns)
X_pred_train.index = train.index

scored_train = pd.DataFrame(index=train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = 0.275
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']

# train 과 test를 동시에 보기 위해서 합침
scored = pd.concat([scored_train, scored])

# %%
scored
# Out:
#                       Loss_mae  Threshold  Anomaly
# 2004-02-12 10:52:39   0.216385      0.275    False
# 2004-02-12 11:02:39   0.242811      0.275    False
# 2004-02-12 11:12:39   0.116898      0.275    False
# 2004-02-12 11:22:39   0.248942      0.275    False
# 2004-02-12 11:32:39   0.167464      0.275    False
# 2004-02-12 11:42:39   0.158816      0.275    False
# 2004-02-12 11:52:39   0.117086      0.275    False
# 2004-02-12 12:02:39   0.225745      0.275    False
# 2004-02-12 12:12:39   0.117162      0.275    False
# 2004-02-12 12:22:39   0.115686      0.275    False
# 2004-02-12 12:32:39   0.123329      0.275    False
# 2004-02-12 12:42:39   0.125985      0.275    False
# 2004-02-12 12:52:39   0.075873      0.275    False
# 2004-02-12 13:02:39   0.098318      0.275    False
# 2004-02-12 13:12:39   0.054766      0.275    False
# 2004-02-12 13:22:39   0.161180      0.275    False
# 2004-02-12 13:32:39   0.078338      0.275    False
# 2004-02-12 13:42:39   0.121632      0.275    False
# 2004-02-12 13:52:39   0.088464      0.275    False
# 2004-02-12 14:02:39   0.123829      0.275    False
# 2004-02-12 14:12:39   0.218519      0.275    False
# 2004-02-12 14:22:39   0.133219      0.275    False
# 2004-02-12 14:32:39   0.039333      0.275    False
# 2004-02-12 14:42:39   0.096579      0.275    False
# 2004-02-12 14:52:39   0.081212      0.275    False
# 2004-02-12 15:02:39   0.063821      0.275    False
# 2004-02-12 15:12:39   0.150241      0.275    False
# 2004-02-12 15:22:39   0.085060      0.275    False
# 2004-02-12 15:32:39   0.148300      0.275    False
# 2004-02-12 15:42:39   0.186930      0.275    False
# ...                        ...        ...      ...
# 2004-02-19 01:32:39   9.378320      0.275     True
# 2004-02-19 01:42:39   7.535012      0.275     True
# 2004-02-19 01:52:39   8.863001      0.275     True
# 2004-02-19 02:02:39   8.079340      0.275     True
# 2004-02-19 02:12:39  10.697750      0.275     True
# 2004-02-19 02:22:39   7.723088      0.275     True
# 2004-02-19 02:32:39  10.251892      0.275     True
# 2004-02-19 02:42:39  12.914745      0.275     True
# 2004-02-19 02:52:39  11.725169      0.275     True
# 2004-02-19 03:02:39   9.440113      0.275     True
# 2004-02-19 03:12:39  10.027070      0.275     True
# 2004-02-19 03:22:39  14.267589      0.275     True
# 2004-02-19 03:32:39  14.639265      0.275     True
# 2004-02-19 03:42:39  17.699527      0.275     True
# 2004-02-19 03:52:39  14.653182      0.275     True
# 2004-02-19 04:02:39  15.508636      0.275     True
# 2004-02-19 04:12:39  18.467042      0.275     True
# 2004-02-19 04:22:39  20.264852      0.275     True
# 2004-02-19 04:32:39  18.824709      0.275     True
# 2004-02-19 04:42:39  14.757779      0.275     True
# 2004-02-19 04:52:39  21.710444      0.275     True
# 2004-02-19 05:02:39  25.395102      0.275     True
# 2004-02-19 05:12:39  22.867449      0.275     True
# 2004-02-19 05:22:39  23.042336      0.275     True
# 2004-02-19 05:32:39  21.155885      0.275     True
# 2004-02-19 05:42:39  30.064355      0.275     True
# 2004-02-19 05:52:39  20.029047      0.275     True
# 2004-02-19 06:02:39  22.371558      0.275     True
# 2004-02-19 06:12:39  11.384650      0.275     True
# 2004-02-19 06:22:39  11.623248      0.275     True
#
# [983 rows x 3 columns]

# %% [markdown]
# Having calculated the loss distribution and the anomaly threshold, we can visualize the model output in the time leading up to the bearing failure.

# %%
# plot bearing failure time plot
scored.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# This analysis approach is able to flag the upcoming bearing malfunction well in advance of the actual physical failure. It is important to define a suitable threshold value for flagging anomalies while avoiding too many false positives during normal operating conditions.

# %%
# save all model information, including weights, in h5 format
model.save("Cloud_model.h5")
print("Model saved")
# Out:
# Model saved

# %%
! python -V
# Out:
# Python 3.6.13 :: Anaconda, Inc.
